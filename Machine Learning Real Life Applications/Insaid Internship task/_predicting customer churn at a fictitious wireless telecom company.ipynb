# %% [markdown]
# ### Importing the data

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading data
dataset=pd.read_csv('C:\\Users\\91870\\Downloads\\Churn.csv')

# %% [markdown]
# ### Understanding the data

# %%
dataset.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
dataset.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# ### Data Manipulation

# %%
#displaying all the index present in data
dataset.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#showing statistics from the present data(Only for columns containg numerical values)
dataset.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# From the statistics above, we can see that the longest tenure is 72 months(6 years), and the maximum monthly charge is $118.75.
#
#
# The  minimum  monthly charge is about $30.09.
#
# The customer can expect to have a monthly charge of about $64.76. I am assuming the charges are in United States Dollars (USD).

# %%
dataset.shape
# Out:
# (7043, 21)

# %% [markdown]
# This data has 21 columns and 7043 rows.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#Checking for missing values
dataset.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# We see here that data does'nt contains any missing values in it.
#
# Now We can do data cleaning through Visualization.

# %% [markdown]
# # Data Visualization

# %%
#Histogram
dataset2=dataset[['tenure','MonthlyCharges']]
fig = plt.figure(figsize=(10,6))
plt.suptitle('Histograms of numerical columns',fontsize=20)
for i in range(1,dataset2.shape[1]):
    plt.subplot(2,1,i)
    f= plt.gca()
    f.axes.get_yaxis().set_visible(False)
    f.set_title(dataset2.columns.values[i])
    
    vals = np.size(dataset2.iloc[:,i].unique())
    plt.hist(dataset2.iloc[:,i],bins=vals,color='blue')
    
plt.tight_layout(rect=[0,0.03,1,0.95])

# %%
#Pie Chart Distribution
dataset2=dataset[['gender', 'SeniorCitizen', 'Partner', 'Dependents',
        'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod']]
fig = plt.figure(figsize=(20,18))
plt.suptitle('Pie Chart Distributions',fontsize=40)

for i in range(1,dataset2.shape[1]):
    plt.subplot(7,3,i)
    f=plt.gca()
    f.axes.get_yaxis().set_visible(False)
    f.set_title(dataset2.columns.values[i])
    
    values = dataset2.iloc[:,i].value_counts(normalize=True).values
    index =  dataset2.iloc[:,i].value_counts(normalize=True).index
    
    plt.pie(values,labels=index,autopct='%1.1f%%')
    plt.axis('equal')

# %% [markdown]
# Through above visualization we get know about distribution of data as details given below:
# 1. We found that only 16.2% of customers are senior citizens.
# 2. Only 9.7% customers are not using phone service available at the connection.
# 3. More than 50% customers have month to month contract.
# 4. Also 70% Customers are dependents.

# %%
dataset[dataset2.SeniorCitizen==0].Churn.value_counts()
# Out:
# No     4508
# Yes    1393
# Name: Churn, dtype: int64

# %%
dataset[dataset2.PhoneService=='Yes'].Churn.value_counts()
# Out:
# No     4662
# Yes    1699
# Name: Churn, dtype: int64

# %% [markdown]
# #### Data Cleaning

# %%
cleaned_data = dataset.drop(columns='customerID')

# %%
cleaned_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
#Getting dummy variables from categorical variables
cleaned_data = pd.get_dummies(cleaned_data,columns=['PaymentMethod','InternetService','Contract'])

# %%
cleaned_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines OnlineSecurity OnlineBackup DeviceProtection  ...  \
# 0  No phone service             No          Yes               No  ...
# 1                No            Yes           No              Yes  ...
# 2                No            Yes          Yes               No  ...
# 3  No phone service            Yes           No              Yes  ...
# 4                No             No           No               No  ...
#
#   PaymentMethod_Bank transfer (automatic)  \
# 0                                       0
# 1                                       0
# ...

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 27 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   gender                                   7043 non-null   object
#  1   SeniorCitizen                            7043 non-null   int64
#  2   Partner                                  7043 non-null   object
#  3   Dependents                               7043 non-null   object
#  4   tenure                                   7043 non-null   int64
#  5   PhoneService                             7043 non-null   object
#  6   MultipleLines                            7043 non-null   object
#  7   OnlineSecurity                           7043 non-null   object
#  8   OnlineBackup                             7043 non-null   object
#  9   DeviceProtection                         7043 non-null   object
# ...

# %%
cleaned_data = cleaned_data.drop(columns=['Contract_Two year','InternetService_No','PaymentMethod_Mailed check'])

# %%
#Encoding categorical variable to numerical variable 
from sklearn.preprocessing import LabelEncoder
for column in cleaned_data.columns:
    if cleaned_data[column].dtype == np.number:
        continue
    cleaned_data[column] = LabelEncoder().fit_transform(cleaned_data[column])

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   gender                                   7043 non-null   int32
#  1   SeniorCitizen                            7043 non-null   int64
#  2   Partner                                  7043 non-null   int32
#  3   Dependents                               7043 non-null   int32
#  4   tenure                                   7043 non-null   int64
#  5   PhoneService                             7043 non-null   int32
#  6   MultipleLines                            7043 non-null   int32
#  7   OnlineSecurity                           7043 non-null   int32
#  8   OnlineBackup                             7043 non-null   int32
#  9   DeviceProtection                         7043 non-null   int32
# ...

# %% [markdown]
# #### Correlation Plot with respect to Target Variable

# %%
#Correlation plot
cleaned_data.drop(columns='Churn').corrwith(cleaned_data.Churn).plot.bar(figsize=(20,10),title='Correlation with Target Variable',fontsize=15,rot=90,grid=True)

# %% [markdown]
# #### Correlation Matrix

# %%
#Correlation Matrix
sns.set(style='white')
corr = cleaned_data.drop(columns=['Churn']).corr()

mask=np.zeros_like(corr,dtype=np.bool)
mask[np.triu_indices_from(mask)]=True

f,ax=plt.subplots(figsize=(15,12))

cmap = sns.diverging_palette(220,10,as_cmap=True)

sns.heatmap(corr,mask=mask,cmap=cmap,vmax=0.3,center=0,square=True,cbar_kws={'shrink':0.5},annot=True)

# %% [markdown]
# ##### From above two visualization, we get to know that gender,PhoneService,TotalCharges are having nearly zeroo correlation with target variable.
# So we can drop them from the data.

# %%
cleaned_data = cleaned_data.drop(columns=['gender','PhoneService','TotalCharges'])

# %%
X = cleaned_data.drop(columns='Churn')
y = cleaned_data['Churn']

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X = sc_X.fit_transform(X)

# %% [markdown]
# #### Splitting The Data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %% [markdown]
# ### Implement Machine Learning Models and Evaluating models

# %% [markdown]
# ##### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(C=0.75,n_jobs=-1,solver='lbfgs',penalty='l2',random_state=0,verbose=5)
classifier.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# LogisticRegression(C=0.75, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=-1, penalty='l2', random_state=0,
#                    solver='lbfgs', tol=0.0001, verbose=5, warm_start=False)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm = confusion_matrix(y_test,y_pred)
print(cm)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[913 110]
#  [183 203]]
# 0.7920511000709723
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1023
#            1       0.65      0.53      0.58       386
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.71      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
#K-Fold CV
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier,X=X_train,y=y_train,cv=10)
print('Accuracy: {:0.2f} % '.format(accuracies.mean()*100))
print('Standard Deviation: {:0.2f} % '.format(accuracies.std()*100))
acc_lr = round(accuracies.mean()*100,2)
std_lr = round(accuracies.std()*100,2)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ...

# %% [markdown]
# ##### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifier2 = RandomForestClassifier(n_estimators=100,random_state=10)
classifier2.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=10, verbose=0,
#                        warm_start=False)

# %%
y_pred2 = classifier2.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm = confusion_matrix(y_test,y_pred2)
print(cm)
print(accuracy_score(y_test,y_pred2))
print(classification_report(y_test,y_pred2))
# Out:
# [[911 112]
#  [191 195]]
# 0.7849538679914834
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1023
#            1       0.64      0.51      0.56       386
#
#     accuracy                           0.78      1409
#    macro avg       0.73      0.70      0.71      1409
# weighted avg       0.77      0.78      0.78      1409

# %%
#K-Fold CV
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier2,X=X_train,y=y_train,cv=10)
print('Accuracy: {:0.2f} % '.format(accuracies.mean()*100))
print('Standard Deviation: {:0.2f} % '.format(accuracies.std()*100))
acc_rf = round(accuracies.mean()*100,2)
std_rf = round(accuracies.std()*100,2)
# Out:
# Accuracy: 78.13 %
# Standard Deviation: 1.22 %

# %% [markdown]
# ##### Support Vector Classifier

# %%
from sklearn.svm import SVC
classifier1 = SVC()
classifier1.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred1 = classifier1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm = confusion_matrix(y_test,y_pred1)
print(cm)
print(accuracy_score(y_test,y_pred1))
print(classification_report(y_test,y_pred1))
# Out:
# [[925  98]
#  [190 196]]
# 0.7955997161107168
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87      1023
#            1       0.67      0.51      0.58       386
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.71      0.72      1409
# weighted avg       0.78      0.80      0.79      1409

# %%
#K-Fold CV
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier1,X=X_train,y=y_train,cv=10)
print('Accuracy: {:0.2f} % '.format(accuracies.mean()*100))
print('Standard Deviation: {:0.2f} % '.format(accuracies.std()*100))
acc_svc = round(accuracies.mean()*100,2)
std_svc = round(accuracies.std()*100,2)
# Out:
# Accuracy: 79.43 %
# Standard Deviation: 1.44 %

# %% [markdown]
# ##### K-NN

# %%
#K-Nearest Neighbours
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors =5,metric='minkowski',p=2)
knn.fit(X_train, y_train)
Y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm = confusion_matrix(y_test,Y_pred)
sns.heatmap(cm,annot=True)
print(accuracy_score(y_test,Y_pred)*100)
print(classification_report(y_test,Y_pred))
# Out:
# 75.01774308019871
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1023
#            1       0.55      0.48      0.52       386
#
#     accuracy                           0.75      1409
#    macro avg       0.68      0.67      0.67      1409
# weighted avg       0.74      0.75      0.75      1409

# %%
#K-Fold CV
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=knn,X=X_train,y=y_train,cv=10)
acc_knn=print('Accuracy: {:0.2f} % '.format(accuracies.mean()*100))
std_knn=print('Standard Deviation: {:0.2f} % '.format(accuracies.std()*100))
acc_knn = round(accuracies.mean()*100,2)
std_knn = round(accuracies.std()*100,2)
# Out:
# Accuracy: 75.98 %
# Standard Deviation: 2.32 %

# %% [markdown]
# ##### Decision Tree

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
print(accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
# Out:
# 73.52732434350602
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82      1023
#            1       0.52      0.50      0.51       386
#
#     accuracy                           0.74      1409
#    macro avg       0.67      0.66      0.66      1409
# weighted avg       0.73      0.74      0.73      1409

# %%
#K-Fold CV
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier,X=X_train,y=y_train,cv=10)
acc_dt=print('Accuracy: {:0.2f} % '.format(accuracies.mean()*100))
std_dt=print('Standard Deviation: {:0.2f} % '.format(accuracies.std()*100))
acc_dt = round(accuracies.mean()*100,2)
std_dt = round(accuracies.std()*100,2)
# Out:
# Accuracy: 72.84 %
# Standard Deviation: 1.24 %

# %% [markdown]
# ##### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
y_pred = gaussian.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
print(accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
# Out:
# 75.37260468417317
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82      1023
#            1       0.54      0.71      0.61       386
#
#     accuracy                           0.75      1409
#    macro avg       0.71      0.74      0.72      1409
# weighted avg       0.78      0.75      0.76      1409

# %%
#K-Fold CV
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=gaussian,X=X_train,y=y_train,cv=10)
acc_nb=print('Accuracy: {:0.2f} % '.format(accuracies.mean()*100))
std_nb=print('Standard Deviation: {:0.2f} % '.format(accuracies.std()*100))
acc_nb = round(accuracies.mean()*100,2)
std_nb = round(accuracies.std()*100,2)
# Out:
# Accuracy: 76.59 %
# Standard Deviation: 1.93 %

# %% [markdown]
# ##### XGboost

# %%
from xgboost import XGBClassifier
classifier = XGBClassifier()
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
print(accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
# Out:
# 78.77927608232788
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1023
#            1       0.64      0.52      0.57       386
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
#K-Fold CV
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier,X=X_train,y=y_train,cv=10)
acc_xg= print('Accuracy: {:0.2f} % '.format(accuracies.mean()*100))
std_xg=print('Standard Deviation: {:0.2f} % '.format(accuracies.std()*100))
acc_xg = round(accuracies.mean()*100,2)
std_xg = round(accuracies.std()*100,2)
# Out:
# Accuracy: 78.66 %
# Standard Deviation: 1.37 %

# %% [markdown]
# ### Concluding Best Model

# %%
models = pd.DataFrame({
    'Classifier Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes',
              'Decision Tree','XgBoost'],
    'Best Score(%)': [acc_svc, acc_knn, acc_lr, 
              acc_rf, acc_nb, acc_dt,acc_xg],
    'Standard Deviation(%)':[std_svc,std_knn,std_lr,
                         std_rf,std_nb,std_dt,std_xg]})
models.sort_values(by='Best Score(%)', ascending=False,ignore_index=True)
# Out:
#           Classifier Model  Best Score(%)  Standard Deviation(%)
# 0      Logistic Regression          80.60                   1.33
# 1  Support Vector Machines          79.43                   1.44
# 2                  XgBoost          78.66                   1.37
# 3            Random Forest          78.13                   1.22
# 4              Naive Bayes          76.59                   1.93
# 5            Decision Tree          72.84                   1.24
# 6                      KNN          72.70                   1.97

# %% [markdown]
# ##### Conclusions:
# We get a remarkable accuracy of 80.60% through Logistic Regression Classifier Model.
# It simply means that we can predict the customer churn at a fictitious wireless telecom company with accuracy of 80.60%.
# Also, we can increase the little bit accuracy of this case by applying parameter tuning to classifier models.
#
#
# To stop customer from churn:
# We can give offer to those customers who are having month-month contract.
# Also We can offer paper billing to senior citizen as may be they don't like paperless billing.
